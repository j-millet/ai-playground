# %%
# %load_ext tensorboard

# %%
import tensorflow as tf
import numpy as np
import tensorboard
print(tf.config.list_physical_devices())
# Out:
# WARNING:tensorflow:From c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
mapping = [
           'apple', 'arm', 'asparagus', 'axe', 'backpack', 'banana', 'bandage', 'barn', 'baseball bat', 'baseball',
           'bench', 'bicycle', 'binoculars', 'bird', 'birthday cake', 'blackberry', 'blueberry', 'book', 'boomerang', 'bottlecap',
           'bush', 'butterfly', 'cactus', 'cake', 'calculator', 'calendar', 'camel', 'camera', 'camouflage', 'campfire',
           'chair', 'chandelier', 'church', 'circle', 'clarinet', 'clock', 'cloud', 'coffee_cup', 'compass', 'computer',
           'diamond', 'dishwasher', 'diving_board', 'dog', 'dolphin', 'donut', 'door', 'dragon', 'dresser', 'drill',
           'harp', 'hat', 'headphones', 'hedgehog', 'helicopter', 'helmet', 'hexagon', 'hockey_puck', 'hockey_stick', 'horse',
           'hospital', 'hot_air_balloon', 'hot_dog', 'hot_tub', 'hourglass', 'house_plant', 'house', 'hurricane', 'ice_cream', 'jacket',
           'paper_clip', 'parachute', 'parrot', 'passport', 'peanut', 'pear', 'peas', 'pencil', 'penguin', 'piano',
           'popsicle', 'postcard', 'potato', 'power_outlet', 'purse', 'rabbit', 'raccoon', 'radio', 'rain', 'rainbow',
           'trombone', 'truck', 'trumpet', 'umbrella', 'underwear', 'van', 'vase', 'violin', 'washing_machine', 'watermelon',
]

# %%
NUM_OBJECTS = 100

# %%
class Generator(tf.keras.utils.Sequence):
    def __init__(self,filenames,labels,batch_size,train=False):
        self.image_filenames = filenames
        self.labels = labels
        self.batch_size = batch_size
        self.train = train
        
    def __len__(self) :
        return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(int)
  
  
    def __getitem__(self, idx) :
        batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
        batch_y = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]

        images = []
        for fname in batch_x:
            with open(fname,"rb") as f:
                images.append(np.divide(np.load(f),255.0))#normalize pixel values
        return np.array(images), np.array(batch_y)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\jake\anaconda3\envs\ai-project\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\jake\anaconda3\envs\ai-project\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\jake\anaconda3\envs\ai-project\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jake\anaconda3\envs\ai-project\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jake\anaconda3\envs\ai-project\lib\site-packages (from scikit-learn) (3.3.0)

# %%
from sklearn.model_selection import train_test_split

filenames = []
labels = []
for lab in range(NUM_OBJECTS):
    labels += [lab for _ in range(10_000)]
    for i in range(10_000):
        filenames.append(f"dataset/images/{lab}/{i}.npy")

labels = tf.keras.utils.to_categorical(labels)


train_X,test_X,train_y,test_y = train_test_split(filenames,labels,test_size=0.1)

train_X,val_X,train_y,val_y = train_test_split(train_X,train_y,test_size=0.22)

train_gen = Generator(train_X,train_y,50)
val_gen = Generator(val_X,val_y,10)

# %%
def get_model(input_shape,num_outputs):
    model = tf.keras.Sequential([
        tf.keras.Input(shape=input_shape),
        tf.keras.layers.Conv2D(16,(3,3),activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2),padding='same'),
        tf.keras.layers.Conv2D(16,(3,3),activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2),padding='same'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1024,activation="relu"),
        tf.keras.layers.Dropout(0.4),
        tf.keras.layers.Dense(256,activation="relu"),
        tf.keras.layers.Dense(num_outputs,activation="softmax") #probability distribution output
    ])
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
        metrics="accuracy"
    )
    model.build()
    return model

# %%
model = get_model((64,64,1),NUM_OBJECTS)
# Out:
# WARNING:tensorflow:From c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
from datetime import datetime
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
model.fit(train_gen,
          epochs=10,
          validation_data=val_gen,
          callbacks=[
              tf.keras.callbacks.ReduceLROnPlateau(
                  monitor='val_accuracy', 
                  patience=3,
                  min_delta=0.0001,
                  factor=0.25,
                  min_lr=0.000001
                ),
              tf.keras.callbacks.EarlyStopping(
                  monitor='val_accuracy', 
                  patience=6, 
                  verbose=2,
                  mode='max',
                  restore_best_weights=True
                ),
              tf.keras.callbacks.ModelCheckpoint(
                     filepath='C:\\Users\\Jake\\Desktop\\ai-playground\\doodle-detection\\models\\model_best.h5', 
                     save_freq='epoch', verbose=1, monitor='val_accuracy', mode="max",
                     save_weights_only=True, save_best_only=True
                ),
              tensorboard_callback
          ])
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 14039/14040 [============================>.] - ETA: 0s - loss: 2.0904 - accuracy: 0.4802
# Epoch 1: val_accuracy improved from -inf to 0.63956, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 853s 61ms/step - loss: 2.0903 - accuracy: 0.4802 - val_loss: 1.3999 - val_accuracy: 0.6396 - lr: 1.0000e-04
# Epoch 2/10
# 14040/14040 [==============================] - ETA: 0s - loss: 1.4502 - accuracy: 0.6242
# Epoch 2: val_accuracy improved from 0.63956 to 0.68803, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 728s 52ms/step - loss: 1.4502 - accuracy: 0.6242 - val_loss: 1.1976 - val_accuracy: 0.6880 - lr: 1.0000e-04
# Epoch 3/10
# 14040/14040 [==============================] - ETA: 0s - loss: 1.2928 - accuracy: 0.6626
# Epoch 3: val_accuracy improved from 0.68803 to 0.70996, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 745s 53ms/step - loss: 1.2928 - accuracy: 0.6626 - val_loss: 1.1106 - val_accuracy: 0.7100 - lr: 1.0000e-04
# Epoch 4/10
# 14039/14040 [============================>.] - ETA: 0s - loss: 1.2046 - accuracy: 0.6839
# Epoch 4: val_accuracy improved from 0.70996 to 0.72241, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 798s 57ms/step - loss: 1.2046 - accuracy: 0.6839 - val_loss: 1.0602 - val_accuracy: 0.7224 - lr: 1.0000e-04
# Epoch 5/10
# 14039/14040 [============================>.] - ETA: 0s - loss: 1.1408 - accuracy: 0.6997
# Epoch 5: val_accuracy improved from 0.72241 to 0.73190, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 789s 56ms/step - loss: 1.1408 - accuracy: 0.6997 - val_loss: 1.0220 - val_accuracy: 0.7319 - lr: 1.0000e-04
# Epoch 6/10
# 14040/14040 [==============================] - ETA: 0s - loss: 1.0923 - accuracy: 0.7108
# Epoch 6: val_accuracy improved from 0.73190 to 0.73986, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 758s 54ms/step - loss: 1.0923 - accuracy: 0.7108 - val_loss: 0.9931 - val_accuracy: 0.7399 - lr: 1.0000e-04
# Epoch 7/10
# 14039/14040 [============================>.] - ETA: 0s - loss: 1.0525 - accuracy: 0.7206
# Epoch 7: val_accuracy improved from 0.73986 to 0.74322, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 715s 51ms/step - loss: 1.0525 - accuracy: 0.7206 - val_loss: 0.9798 - val_accuracy: 0.7432 - lr: 1.0000e-04
# Epoch 8/10
# 14040/14040 [==============================] - ETA: 0s - loss: 1.0200 - accuracy: 0.7280
# Epoch 8: val_accuracy improved from 0.74322 to 0.74777, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 682s 49ms/step - loss: 1.0200 - accuracy: 0.7280 - val_loss: 0.9603 - val_accuracy: 0.7478 - lr: 1.0000e-04
# Epoch 9/10
# 14040/14040 [==============================] - ETA: 0s - loss: 0.9884 - accuracy: 0.7354
# Epoch 9: val_accuracy improved from 0.74777 to 0.75044, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 715s 51ms/step - loss: 0.9884 - accuracy: 0.7354 - val_loss: 0.9523 - val_accuracy: 0.7504 - lr: 1.0000e-04
# Epoch 10/10
# 14040/14040 [==============================] - ETA: 0s - loss: 0.9622 - accuracy: 0.7413
# Epoch 10: val_accuracy improved from 0.75044 to 0.75224, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 704s 50ms/step - loss: 0.9622 - accuracy: 0.7413 - val_loss: 0.9437 - val_accuracy: 0.7522 - lr: 1.0000e-04

# %%
model.load_weights('C:\\Users\\Jake\\Desktop\\ai-playground\\doodle-detection\\models\\model_best.h5')

# %%
model.evaluate(Generator(test_X,test_y,10))
# Out:
#  3805/10000 [==========>...................] - ETA: 26s - loss: 0.9590 - accuracy: 0.7503
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 model.evaluate(Generator(test_X,test_y,10))
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\engine\training.py:2296, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2292             with tf.profiler.experimental.Trace(
#    2293                 "test", step_num=step, _r=1
#    2294             ):
#    2295                 callbacks.on_test_batch_begin(step)
# -> 2296                 logs = test_function_runner.run_step(
#    2297                     dataset_or_iterator,
#    2298                     data_handler,
#    2299                     step,
#    2300                     self._pss_evaluation_shards,
#    2301                 )
#    2303 logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    2304 # Override with model metrics instead of last step logs
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\engine\training.py:4108, in _TestFunction.run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    4107 def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4108     tmp_logs = self._function(dataset_or_iterator)
#    4109     if data_handler.should_sync:
#    4110         context.async_wait()
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:877, in Function._call(self, *args, **kwds)
#     874 self._lock.release()
#     875 # In this case we have not created variables on the first call. So we can
#     876 # run the first trace but we should fail if variables are created.
# --> 877 results = tracing_compilation.call_function(
#     878     args, kwds, self._variable_creation_config
#     879 )
#     880 if self._created_variables:
#     881   raise ValueError("Creating variables on a non-first call to a function"
#     882                    " decorated with tf.function.")
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save('C:\\Users\\Jake\\Desktop\\ai-playground\\doodle-detection\\models\\model_100obj.h5')
# Out:
# c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt


for i in range(50):
    fname = test_X[i]
    img = None
    with open(fname,"rb") as f:
        img = np.divide(np.load(f),255.0)
    print(img.shape)
    plt.imshow(img, interpolation='nearest')
    plt.show()
    
    label = np.argmax(test_y[i])
    pred = model.predict(Generator([fname],[label],1))[0]
    pred_label = np.argmax(pred)
    perc = pred[pred_label]
    print(f'TRUE: {mapping[label]},PREDICT: {mapping[pred_label]}, {round(perc*100,2)}%')
# Out:
# (64, 64, 1)
# 1/1 [==============================] - 1s 886ms/step
# TRUE: door,PREDICT: door, 99.9%
# (64, 64, 1)
# 1/1 [==============================] - 0s 45ms/step
# TRUE: hourglass,PREDICT: hourglass, 95.95%
# (64, 64, 1)
# 1/1 [==============================] - 0s 48ms/step
# TRUE: hot_dog,PREDICT: trumpet, 32.85%
# (64, 64, 1)
# 1/1 [==============================] - 0s 56ms/step
# TRUE: blackberry,PREDICT: blackberry, 56.23%
# (64, 64, 1)
# 1/1 [==============================] - 0s 45ms/step
# TRUE: penguin,PREDICT: penguin, 98.51%
# (64, 64, 1)
# 1/1 [==============================] - 0s 50ms/step
# TRUE: hexagon,PREDICT: hexagon, 99.99%
# (64, 64, 1)
# 1/1 [==============================] - 0s 45ms/step
# TRUE: rain,PREDICT: rain, 66.63%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: blackberry,PREDICT: peas, 15.56%
# (64, 64, 1)
# 1/1 [==============================] - 0s 51ms/step
# TRUE: hedgehog,PREDICT: campfire, 49.52%
# (64, 64, 1)
# 1/1 [==============================] - 0s 49ms/step
# TRUE: binoculars,PREDICT: binoculars, 99.98%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: violin,PREDICT: violin, 46.24%
# (64, 64, 1)
# 1/1 [==============================] - 0s 34ms/step
# TRUE: blueberry,PREDICT: blueberry, 51.72%
# (64, 64, 1)
# 1/1 [==============================] - 0s 33ms/step
# TRUE: bench,PREDICT: bench, 92.08%
# (64, 64, 1)
# 1/1 [==============================] - 0s 33ms/step
# TRUE: jacket,PREDICT: jacket, 99.98%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: helicopter,PREDICT: helicopter, 87.78%
# (64, 64, 1)
# 1/1 [==============================] - 0s 40ms/step
# TRUE: baseball bat,PREDICT: baseball bat, 78.75%
# (64, 64, 1)
# 1/1 [==============================] - 0s 50ms/step
# TRUE: blueberry,PREDICT: parrot, 14.09%
# (64, 64, 1)
# 1/1 [==============================] - 0s 34ms/step
# TRUE: diving_board,PREDICT: diving_board, 94.5%
# (64, 64, 1)
# 1/1 [==============================] - 0s 53ms/step
# TRUE: harp,PREDICT: harp, 99.09%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: camel,PREDICT: camel, 99.86%
# (64, 64, 1)
# 1/1 [==============================] - 0s 43ms/step
# TRUE: dishwasher,PREDICT: computer, 95.91%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: cactus,PREDICT: hospital, 52.57%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: hockey_puck,PREDICT: hockey_puck, 85.4%
# (64, 64, 1)
# 1/1 [==============================] - 0s 51ms/step
# TRUE: cactus,PREDICT: butterfly, 79.85%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: jacket,PREDICT: jacket, 96.41%
# (64, 64, 1)
# 1/1 [==============================] - 0s 39ms/step
# TRUE: ice_cream,PREDICT: ice_cream, 99.97%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: butterfly,PREDICT: butterfly, 99.86%
# (64, 64, 1)
# 1/1 [==============================] - 0s 34ms/step
# TRUE: purse,PREDICT: cake, 53.65%
# (64, 64, 1)
# 1/1 [==============================] - 0s 34ms/step
# TRUE: asparagus,PREDICT: asparagus, 74.89%
# (64, 64, 1)
# 1/1 [==============================] - 0s 33ms/step
# TRUE: diving_board,PREDICT: bench, 74.1%
# (64, 64, 1)
# 1/1 [==============================] - 0s 46ms/step
# TRUE: purse,PREDICT: purse, 59.98%
# (64, 64, 1)
# 1/1 [==============================] - 0s 37ms/step
# TRUE: pencil,PREDICT: diving_board, 74.42%
# (64, 64, 1)
# 1/1 [==============================] - 0s 37ms/step
# TRUE: dishwasher,PREDICT: dishwasher, 38.47%
# (64, 64, 1)
# 1/1 [==============================] - 0s 32ms/step
# TRUE: watermelon,PREDICT: watermelon, 94.06%
# (64, 64, 1)
# 1/1 [==============================] - 0s 32ms/step
# TRUE: computer,PREDICT: computer, 97.48%
# (64, 64, 1)
# 1/1 [==============================] - 0s 33ms/step
# TRUE: bottlecap,PREDICT: bottlecap, 79.97%
# (64, 64, 1)
# 1/1 [==============================] - 0s 33ms/step
# TRUE: door,PREDICT: door, 98.91%
# (64, 64, 1)
# 1/1 [==============================] - 0s 34ms/step
# TRUE: chair,PREDICT: chair, 99.74%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: bird,PREDICT: bird, 25.18%
# (64, 64, 1)
# 1/1 [==============================] - 0s 34ms/step
# TRUE: violin,PREDICT: violin, 48.25%
# (64, 64, 1)
# 1/1 [==============================] - 0s 39ms/step
# TRUE: parrot,PREDICT: parrot, 62.1%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: cloud,PREDICT: cloud, 89.89%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: cloud,PREDICT: cloud, 53.02%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: rainbow,PREDICT: rainbow, 96.75%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: birthday cake,PREDICT: hedgehog, 33.15%
# (64, 64, 1)
# 1/1 [==============================] - 0s 34ms/step
# TRUE: binoculars,PREDICT: binoculars, 99.66%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: radio,PREDICT: radio, 56.53%
# (64, 64, 1)
# 1/1 [==============================] - 0s 32ms/step
# TRUE: bicycle,PREDICT: bicycle, 83.95%
# (64, 64, 1)
# 1/1 [==============================] - 0s 34ms/step
# TRUE: cloud,PREDICT: raccoon, 18.64%
# (64, 64, 1)
# 1/1 [==============================] - 0s 37ms/step
# TRUE: rabbit,PREDICT: rabbit, 95.91%
