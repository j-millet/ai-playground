# %%
# %load_ext tensorboard

# %%
import tensorflow as tf
import numpy as np
import tensorboard
print(tf.config.list_physical_devices())
# Out:
# WARNING:tensorflow:From c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
mapping = [
           'apple', 'arm', 'asparagus', 'axe', 'backpack', 'banana', 'bandage', 'barn', 'baseball bat', 'baseball',
           'bench', 'bicycle', 'binoculars', 'bird', 'birthday cake', 'blackberry', 'blueberry', 'book', 'boomerang', 'bottlecap',
           'bush', 'butterfly', 'cactus', 'cake', 'calculator', 'calendar', 'camel', 'camera', 'camouflage', 'campfire',
           'chair', 'chandelier', 'church', 'circle', 'clarinet', 'clock', 'cloud', 'coffee_cup', 'compass', 'computer',
           'diamond', 'dishwasher', 'diving_board', 'dog', 'dolphin', 'donut', 'door', 'dragon', 'dresser', 'drill',
           'harp', 'hat', 'headphones', 'hedgehog', 'helicopter', 'helmet', 'hexagon', 'hockey_puck', 'hockey_stick', 'horse',
           'hospital', 'hot_air_balloon', 'hot_dog', 'hot_tub', 'hourglass', 'house_plant', 'house', 'hurricane', 'ice_cream', 'jacket',
           'paper_clip', 'parachute', 'parrot', 'passport', 'peanut', 'pear', 'peas', 'pencil', 'penguin', 'piano',
           'popsicle', 'postcard', 'potato', 'power_outlet', 'purse', 'rabbit', 'raccoon', 'radio', 'rain', 'rainbow',
           'trombone', 'truck', 'trumpet', 'umbrella', 'underwear', 'van', 'vase', 'violin', 'washing_machine', 'watermelon',
]

# %%
NUM_OBJECTS = 100

# %%
class Generator(tf.keras.utils.Sequence):
    def __init__(self,filenames,labels,batch_size,train=False):
        self.image_filenames = filenames
        self.labels = labels
        self.batch_size = batch_size
        self.train = train
        
    def __len__(self) :
        return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(int)
  
  
    def __getitem__(self, idx) :
        batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
        batch_y = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]

        images = []
        for fname in batch_x:
            with open(fname,"rb") as f:
                images.append(np.divide(np.load(f),255.0))#normalize pixel values
        return np.array(images), np.array(batch_y)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\jake\anaconda3\envs\ai-project\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\jake\anaconda3\envs\ai-project\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\jake\anaconda3\envs\ai-project\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jake\anaconda3\envs\ai-project\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jake\anaconda3\envs\ai-project\lib\site-packages (from scikit-learn) (3.3.0)

# %%
from sklearn.model_selection import train_test_split

filenames = []
labels = []
for lab in range(NUM_OBJECTS):
    labels += [lab for _ in range(10_000)]
    for i in range(10_000):
        filenames.append(f"dataset/images/{lab}/{i}.npy")

labels = tf.keras.utils.to_categorical(labels)


train_X,test_X,train_y,test_y = train_test_split(filenames,labels,test_size=0.1)

train_X,val_X,train_y,val_y = train_test_split(train_X,train_y,test_size=0.22)

train_gen = Generator(train_X,train_y,50)
val_gen = Generator(val_X,val_y,10)

# %%
def get_model(input_shape,num_outputs):
    model = tf.keras.Sequential([
        tf.keras.Input(shape=input_shape),
        tf.keras.layers.Conv2D(16,(3,3),activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2),padding='same'),
        tf.keras.layers.Conv2D(16,(3,3),activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2),padding='same'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1024,activation="relu"),
        tf.keras.layers.Dropout(0.4),
        tf.keras.layers.Dense(256,activation="relu"),
        tf.keras.layers.Dense(num_outputs,activation="softmax") #probability distribution output
    ])
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
        metrics="accuracy"
    )
    model.build()
    return model

# %%
model = get_model((64,64,1),NUM_OBJECTS)
# Out:
# WARNING:tensorflow:From c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
from datetime import datetime
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
model.fit(train_gen,
          epochs=50,
          validation_data=val_gen,
          callbacks=[
              tf.keras.callbacks.ReduceLROnPlateau(
                  monitor='val_accuracy', 
                  patience=3,
                  min_delta=0.0001,
                  factor=0.25,
                  min_lr=0.000001
                ),
              tf.keras.callbacks.EarlyStopping(
                  monitor='val_accuracy', 
                  patience=6, 
                  verbose=2,
                  mode='max',
                  restore_best_weights=True
                ),
              tf.keras.callbacks.ModelCheckpoint(
                     filepath='C:\\Users\\Jake\\Desktop\\ai-playground\\doodle-detection\\models\\model_best.h5', 
                     save_freq='epoch', verbose=1, monitor='val_accuracy', mode="max",
                     save_weights_only=True, save_best_only=True
                ),
              tensorboard_callback
          ])
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 14040/14040 [==============================] - ETA: 0s - loss: 1.8746 - accuracy: 0.5300
# Epoch 1: val_accuracy improved from -inf to 0.66509, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 1173s 83ms/step - loss: 1.8746 - accuracy: 0.5300 - val_loss: 1.2892 - val_accuracy: 0.6651 - lr: 1.0000e-04
# Epoch 2/50
# 14040/14040 [==============================] - ETA: 0s - loss: 1.3049 - accuracy: 0.6604
# Epoch 2: val_accuracy improved from 0.66509 to 0.70811, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 1002s 71ms/step - loss: 1.3049 - accuracy: 0.6604 - val_loss: 1.1184 - val_accuracy: 0.7081 - lr: 1.0000e-04
# Epoch 3/50
# 14040/14040 [==============================] - ETA: 0s - loss: 1.1597 - accuracy: 0.6954
# Epoch 3: val_accuracy improved from 0.70811 to 0.72662, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 1031s 73ms/step - loss: 1.1597 - accuracy: 0.6954 - val_loss: 1.0461 - val_accuracy: 0.7266 - lr: 1.0000e-04
# Epoch 4/50
# 14040/14040 [==============================] - ETA: 0s - loss: 1.0704 - accuracy: 0.7171
# Epoch 4: val_accuracy improved from 0.72662 to 0.73707, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 1024s 73ms/step - loss: 1.0704 - accuracy: 0.7171 - val_loss: 1.0026 - val_accuracy: 0.7371 - lr: 1.0000e-04
# Epoch 5/50
# 14040/14040 [==============================] - ETA: 0s - loss: 1.0053 - accuracy: 0.7327
# Epoch 5: val_accuracy improved from 0.73707 to 0.74675, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 1136s 81ms/step - loss: 1.0053 - accuracy: 0.7327 - val_loss: 0.9660 - val_accuracy: 0.7467 - lr: 1.0000e-04
# Epoch 6/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.9515 - accuracy: 0.7457
# Epoch 6: val_accuracy improved from 0.74675 to 0.75106, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 992s 71ms/step - loss: 0.9515 - accuracy: 0.7457 - val_loss: 0.9489 - val_accuracy: 0.7511 - lr: 1.0000e-04
# Epoch 7/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.9076 - accuracy: 0.7565
# Epoch 7: val_accuracy improved from 0.75106 to 0.75507, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 928s 66ms/step - loss: 0.9076 - accuracy: 0.7565 - val_loss: 0.9347 - val_accuracy: 0.7551 - lr: 1.0000e-04
# Epoch 8/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.8659 - accuracy: 0.7657
# Epoch 8: val_accuracy improved from 0.75507 to 0.75601, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 947s 67ms/step - loss: 0.8659 - accuracy: 0.7657 - val_loss: 0.9321 - val_accuracy: 0.7560 - lr: 1.0000e-04
# Epoch 9/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.8304 - accuracy: 0.7744
# Epoch 9: val_accuracy improved from 0.75601 to 0.76009, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 953s 68ms/step - loss: 0.8304 - accuracy: 0.7744 - val_loss: 0.9221 - val_accuracy: 0.7601 - lr: 1.0000e-04
# Epoch 10/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.7978 - accuracy: 0.7819
# Epoch 10: val_accuracy improved from 0.76009 to 0.76169, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 920s 66ms/step - loss: 0.7978 - accuracy: 0.7819 - val_loss: 0.9206 - val_accuracy: 0.7617 - lr: 1.0000e-04
# Epoch 11/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.7662 - accuracy: 0.7886
# Epoch 11: val_accuracy did not improve from 0.76169
# 14040/14040 [==============================] - 917s 65ms/step - loss: 0.7662 - accuracy: 0.7886 - val_loss: 0.9217 - val_accuracy: 0.7612 - lr: 1.0000e-04
# Epoch 12/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.7371 - accuracy: 0.7966
# Epoch 12: val_accuracy improved from 0.76169 to 0.76179, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 914s 65ms/step - loss: 0.7371 - accuracy: 0.7966 - val_loss: 0.9261 - val_accuracy: 0.7618 - lr: 1.0000e-04
# Epoch 13/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.8024
# Epoch 13: val_accuracy improved from 0.76179 to 0.76350, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 989s 70ms/step - loss: 0.7090 - accuracy: 0.8024 - val_loss: 0.9253 - val_accuracy: 0.7635 - lr: 1.0000e-04
# Epoch 14/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.6829 - accuracy: 0.8086
# Epoch 14: val_accuracy improved from 0.76350 to 0.76405, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 922s 66ms/step - loss: 0.6829 - accuracy: 0.8086 - val_loss: 0.9238 - val_accuracy: 0.7640 - lr: 1.0000e-04
# Epoch 15/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.6596 - accuracy: 0.8140
# Epoch 15: val_accuracy did not improve from 0.76405
# 14040/14040 [==============================] - 931s 66ms/step - loss: 0.6596 - accuracy: 0.8140 - val_loss: 0.9311 - val_accuracy: 0.7637 - lr: 1.0000e-04
# Epoch 16/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.6353 - accuracy: 0.8200
# Epoch 16: val_accuracy did not improve from 0.76405
# 14040/14040 [==============================] - 910s 65ms/step - loss: 0.6353 - accuracy: 0.8200 - val_loss: 0.9445 - val_accuracy: 0.7626 - lr: 1.0000e-04
# Epoch 17/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.6136 - accuracy: 0.8249
# Epoch 17: val_accuracy did not improve from 0.76405
# 14040/14040 [==============================] - 935s 67ms/step - loss: 0.6136 - accuracy: 0.8249 - val_loss: 0.9632 - val_accuracy: 0.7613 - lr: 1.0000e-04
# Epoch 18/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.5307 - accuracy: 0.8483
# Epoch 18: val_accuracy improved from 0.76405 to 0.76711, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 927s 66ms/step - loss: 0.5307 - accuracy: 0.8483 - val_loss: 0.9622 - val_accuracy: 0.7671 - lr: 2.5000e-05
# Epoch 19/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.5075 - accuracy: 0.8538
# Epoch 19: val_accuracy did not improve from 0.76711
# 14040/14040 [==============================] - 1007s 72ms/step - loss: 0.5075 - accuracy: 0.8538 - val_loss: 0.9638 - val_accuracy: 0.7668 - lr: 2.5000e-05
# Epoch 20/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4932 - accuracy: 0.8579
# Epoch 20: val_accuracy did not improve from 0.76711
# 14040/14040 [==============================] - 1011s 72ms/step - loss: 0.4932 - accuracy: 0.8579 - val_loss: 0.9746 - val_accuracy: 0.7668 - lr: 2.5000e-05
# Epoch 21/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4806 - accuracy: 0.8613
# Epoch 21: val_accuracy did not improve from 0.76711
# 14040/14040 [==============================] - 968s 69ms/step - loss: 0.4806 - accuracy: 0.8613 - val_loss: 0.9820 - val_accuracy: 0.7662 - lr: 2.5000e-05
# Epoch 22/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4566 - accuracy: 0.8677
# Epoch 22: val_accuracy did not improve from 0.76711
# 14040/14040 [==============================] - 1044s 74ms/step - loss: 0.4566 - accuracy: 0.8677 - val_loss: 0.9884 - val_accuracy: 0.7670 - lr: 6.2500e-06
# Epoch 23/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4513 - accuracy: 0.8691
# Epoch 23: val_accuracy improved from 0.76711 to 0.76717, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 975s 69ms/step - loss: 0.4513 - accuracy: 0.8691 - val_loss: 0.9901 - val_accuracy: 0.7672 - lr: 6.2500e-06
# Epoch 24/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4488 - accuracy: 0.8699
# Epoch 24: val_accuracy improved from 0.76717 to 0.76727, saving model to C:\Users\Jake\Desktop\ai-playground\doodle-detection\models\model_best.h5
# 14040/14040 [==============================] - 936s 67ms/step - loss: 0.4488 - accuracy: 0.8699 - val_loss: 0.9918 - val_accuracy: 0.7673 - lr: 6.2500e-06
# Epoch 25/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4449 - accuracy: 0.8705
# Epoch 25: val_accuracy did not improve from 0.76727
# 14040/14040 [==============================] - 973s 69ms/step - loss: 0.4449 - accuracy: 0.8705 - val_loss: 0.9950 - val_accuracy: 0.7669 - lr: 6.2500e-06
# Epoch 26/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4422 - accuracy: 0.8715
# Epoch 26: val_accuracy did not improve from 0.76727
# 14040/14040 [==============================] - 927s 66ms/step - loss: 0.4422 - accuracy: 0.8715 - val_loss: 0.9984 - val_accuracy: 0.7666 - lr: 6.2500e-06
# Epoch 27/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4383 - accuracy: 0.8729
# Epoch 27: val_accuracy did not improve from 0.76727
# 14040/14040 [==============================] - 927s 66ms/step - loss: 0.4383 - accuracy: 0.8729 - val_loss: 1.0005 - val_accuracy: 0.7667 - lr: 6.2500e-06
# Epoch 28/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4327 - accuracy: 0.8743
# Epoch 28: val_accuracy did not improve from 0.76727
# 14040/14040 [==============================] - 937s 67ms/step - loss: 0.4327 - accuracy: 0.8743 - val_loss: 1.0005 - val_accuracy: 0.7667 - lr: 1.5625e-06
# Epoch 29/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4309 - accuracy: 0.8745
# Epoch 29: val_accuracy did not improve from 0.76727
# 14040/14040 [==============================] - 948s 68ms/step - loss: 0.4309 - accuracy: 0.8745 - val_loss: 1.0013 - val_accuracy: 0.7668 - lr: 1.5625e-06
# Epoch 30/50
# 14040/14040 [==============================] - ETA: 0s - loss: 0.4302 - accuracy: 0.8745Restoring model weights from the end of the best epoch: 24.
#
# Epoch 30: val_accuracy did not improve from 0.76727
# 14040/14040 [==============================] - 923s 66ms/step - loss: 0.4302 - accuracy: 0.8745 - val_loss: 1.0023 - val_accuracy: 0.7669 - lr: 1.5625e-06
# Epoch 30: early stopping

# %%
model.load_weights('C:\\Users\\Jake\\Desktop\\ai-playground\\doodle-detection\\models\\model_best.h5')

# %%
model.evaluate(Generator(test_X,test_y,10))
# Out:
# 10000/10000 [==============================] - 74s 7ms/step - loss: 0.9708 - accuracy: 0.7697
# [0.9707586765289307, 0.7696800231933594]

# %%
model.save('C:\\Users\\Jake\\Desktop\\ai-playground\\doodle-detection\\models\\model_100obj.h5')
# Out:
# c:\Users\Jake\anaconda3\envs\ai-project\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt


for i in range(50):
    fname = test_X[i]
    img = None
    with open(fname,"rb") as f:
        img = np.divide(np.load(f),255.0)
    print(img.shape)
    plt.imshow(img, interpolation='nearest')
    plt.show()
    
    label = np.argmax(test_y[i])
    pred = model.predict(Generator([fname],[label],1))[0]
    pred_label = np.argmax(pred)
    perc = pred[pred_label]
    print(f'TRUE: {mapping[label]},PREDICT: {mapping[pred_label]}, {round(perc*100,2)}%')
# Out:
# (64, 64, 1)
# 1/1 [==============================] - 0s 39ms/step
# TRUE: parachute,PREDICT: parachute, 99.99%
# (64, 64, 1)
# 1/1 [==============================] - 0s 45ms/step
# TRUE: dishwasher,PREDICT: dishwasher, 93.73%
# (64, 64, 1)
# 1/1 [==============================] - 0s 34ms/step
# TRUE: penguin,PREDICT: penguin, 99.94%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: cloud,PREDICT: bush, 77.51%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: blueberry,PREDICT: blueberry, 99.02%
# (64, 64, 1)
# 1/1 [==============================] - 0s 55ms/step
# TRUE: penguin,PREDICT: penguin, 73.02%
# (64, 64, 1)
# 1/1 [==============================] - 0s 41ms/step
# TRUE: paper_clip,PREDICT: paper_clip, 98.33%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: van,PREDICT: van, 99.05%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: baseball,PREDICT: baseball, 99.97%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: raccoon,PREDICT: raccoon, 99.35%
# (64, 64, 1)
# 1/1 [==============================] - 0s 74ms/step
# TRUE: door,PREDICT: door, 99.76%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: raccoon,PREDICT: raccoon, 59.6%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: dog,PREDICT: dog, 94.07%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: diving_board,PREDICT: diving_board, 38.06%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: backpack,PREDICT: backpack, 83.01%
# (64, 64, 1)
# 1/1 [==============================] - 0s 45ms/step
# TRUE: blueberry,PREDICT: blueberry, 92.12%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: underwear,PREDICT: underwear, 99.96%
# (64, 64, 1)
# 1/1 [==============================] - 0s 40ms/step
# TRUE: butterfly,PREDICT: butterfly, 100.0%
# (64, 64, 1)
# 1/1 [==============================] - 0s 50ms/step
# TRUE: blueberry,PREDICT: bush, 39.46%
# (64, 64, 1)
# 1/1 [==============================] - 0s 93ms/step
# TRUE: washing_machine,PREDICT: washing_machine, 97.33%
# (64, 64, 1)
# 1/1 [==============================] - 0s 42ms/step
# TRUE: rainbow,PREDICT: rainbow, 99.53%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: vase,PREDICT: bottlecap, 80.47%
# (64, 64, 1)
# 1/1 [==============================] - 0s 37ms/step
# TRUE: camera,PREDICT: camera, 99.96%
# (64, 64, 1)
# 1/1 [==============================] - 0s 44ms/step
# TRUE: parachute,PREDICT: parachute, 99.96%
# (64, 64, 1)
# 1/1 [==============================] - 0s 37ms/step
# TRUE: asparagus,PREDICT: asparagus, 99.98%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: violin,PREDICT: violin, 99.91%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: watermelon,PREDICT: clock, 45.29%
# (64, 64, 1)
# 1/1 [==============================] - 0s 41ms/step
# TRUE: birthday cake,PREDICT: birthday cake, 53.72%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: watermelon,PREDICT: watermelon, 99.94%
# (64, 64, 1)
# 1/1 [==============================] - 0s 37ms/step
# TRUE: camera,PREDICT: camera, 99.86%
# (64, 64, 1)
# 1/1 [==============================] - 0s 54ms/step
# TRUE: power_outlet,PREDICT: power_outlet, 28.89%
# (64, 64, 1)
# 1/1 [==============================] - 0s 41ms/step
# TRUE: radio,PREDICT: birthday cake, 89.27%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: jacket,PREDICT: jacket, 99.85%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: dishwasher,PREDICT: dresser, 77.29%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: barn,PREDICT: barn, 97.25%
# (64, 64, 1)
# 1/1 [==============================] - 0s 39ms/step
# TRUE: popsicle,PREDICT: popsicle, 99.96%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: campfire,PREDICT: campfire, 98.76%
# (64, 64, 1)
# 1/1 [==============================] - 0s 37ms/step
# TRUE: backpack,PREDICT: backpack, 66.97%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: bush,PREDICT: camel, 93.04%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: trumpet,PREDICT: trumpet, 98.43%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: cake,PREDICT: birthday cake, 83.75%
# (64, 64, 1)
# 1/1 [==============================] - 0s 39ms/step
# TRUE: cactus,PREDICT: cactus, 100.0%
# (64, 64, 1)
# 1/1 [==============================] - 0s 97ms/step
# TRUE: piano,PREDICT: binoculars, 41.67%
# (64, 64, 1)
# 1/1 [==============================] - 0s 50ms/step
# TRUE: radio,PREDICT: radio, 100.0%
# (64, 64, 1)
# 1/1 [==============================] - 0s 73ms/step
# TRUE: calculator,PREDICT: calculator, 99.95%
# (64, 64, 1)
# 1/1 [==============================] - 0s 51ms/step
# TRUE: parrot,PREDICT: parrot, 95.69%
# (64, 64, 1)
# 1/1 [==============================] - 0s 36ms/step
# TRUE: bird,PREDICT: bird, 98.81%
# (64, 64, 1)
# 1/1 [==============================] - 0s 37ms/step
# TRUE: peanut,PREDICT: peanut, 94.84%
# (64, 64, 1)
# 1/1 [==============================] - 0s 35ms/step
# TRUE: radio,PREDICT: radio, 100.0%
# (64, 64, 1)
# 1/1 [==============================] - 0s 38ms/step
# TRUE: axe,PREDICT: asparagus, 69.87%
